# %% [markdown]
# ### **Customer's Sales Data Insights**

# %%
import pandas as pd                                                       #Import useful libraries
import numpy as np
from datetime import datetime


col_name = ['domain_name', 'users', 'plan', 'price', 'event_id', 'joined_participants', 'active_participants', 'avg_join', 
             'avg_active', 'date_signup', 'date_subscription', 'date']

data = pd.read_csv("/_data.db.csv", names=col_name, low_memory=False) 

data_all = data.iloc[0:,:]
data.head()
# Out:
#          domain_name  users          plan  price  event_id  \
# 0            lee.com     16  Professional   5400         7
# 1  francis-ellis.com     19  Professional   6300         8
# 2           hale.com     20  Professional   6600        16
# 3        mcclure.com      5    Enterprise   4200        17
# 4       robinson.biz      5    Enterprise   4200        27
#
#    joined_participants  active_participants  avg_join  avg_active date_signup  \
# 0                  143                   88       143          88  2020-02-12
# 1                   80                   68        80          68  2020-11-09
# 2                   93                   51        93          51  2020-06-08
# 3                  136                  128       136         128  2020-05-04
# 4                  161                   93       161          93  2020-01-25
#
#   date_subscription        date
# 0        2020-02-12  2020-12-29
# 1        2020-11-16  2021-02-05
# 2        2020-07-18  2021-01-23
# 3        2020-05-21  2021-01-09
# 4        2020-02-26  2020-10-27

# %%
# Check for duplicates
data.duplicated().sum()
# Out:
# 0

# %%
# Check for null values
data.isnull().sum()
# Out:
# domain_name            0
# users                  0
# plan                   0
# price                  0
# event_id               0
# joined_participants    0
# active_participants    0
# avg_join               0
# avg_active             0
# date_signup            0
# date_subscription      0
# date                   0
# dtype: int64

# %%
#Information on features 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   domain_name          614 non-null    object
#  1   users                614 non-null    int64
#  2   plan                 614 non-null    object
#  3   price                614 non-null    int64
#  4   event_id             614 non-null    int64
#  5   joined_participants  614 non-null    int64
#  6   active_participants  614 non-null    int64
#  7   avg_join             614 non-null    int64
#  8   avg_active           614 non-null    int64
#  9   date_signup          614 non-null    object
#  10  date_subscription    614 non-null    object
#  11  date                 614 non-null    object
# dtypes: int64(7), object(5)
# memory usage: 57.7+ KB

# %% [markdown]
# #Neccessary libraries for Analysis:

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import colors
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt, numpy as np
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import AgglomerativeClustering
from matplotlib.colors import ListedColormap
from sklearn import metrics
import warnings
import sys

if not sys.warnoptions:
    warnings.simplefilter("ignore")
np.random.seed(42)

import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", 150)
pd.set_option('display.max_rows', 999)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# #Exploratory Data Analysis (EDA):

# %%
print("There are \033[1m{} companies\033[0m ".format(len(data_all['domain_name'].value_counts().to_list())))
# Out:
# There are 20 companies

# %%
#Print out all unique Companies domain name

data['domain_name'].unique()
# Out:
# array(['lee.com', 'francis-ellis.com', 'hale.com', 'mcclure.com',
#        'robinson.biz', 'roy.net', 'sutton.com', 'martin.net',
#        'atkinson.org', 'turner.biz', 'keller-potter.net', 'gar',
#        'guerrero.com', 'jones-bradley.com', 'soto.biz', 'edwards.com',
#        'frank-mahoney.biz', 'smith.com', 'wilson.org', 'garcia.biz'],
#       dtype=object)

# %%
fig = px.treemap(data_all, path=['domain_name'], color='domain_name')
fig.update_layout(margin = dict(t=60, l=15, r=15, b=15),
                  title_text="<b>Companies Distribution</b>",
                  title_x=0.5,
                  font=dict(family="serif", size=20, color='#000000'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8f18a531-cb8e-493f-8309-d1242809cb34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f18a531-cb8e-493f-8309-d1242809cb34")) {                    Plotly.newPlot(                        "8f18a531-cb8e-493f-8309-d1242809cb34",                        [{"branchvalues":"total","customdata":[["keller-potter.net"],["edwards.com"],["robinson.biz"],["smith.com"],["francis-ellis.com"],["turner.biz"],["martin.net"],["roy.net"],["atkinson.org"],["hale.com"],["mcclure.com"],["sutton.com"],["frank-mahoney.biz"],["soto.biz"],["jones-bradley.com"],["gar"],["wilson.org"],["garcia.biz"],["guerrero.com"],["lee.com"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<br>domain_name=%{customdata[0]}<extra></extra>","ids":["keller-potter.net","edwards.com","robinson.biz","smith.com","francis-ellis.com","turner.biz","martin.net","roy.net","atkinson.org","hale.com","mcclure.com","sutton.com","frank-mahoney.biz","soto.biz","jones-bradley.com","gar","wilson.org","garcia.biz","guerrero.com","lee.com"],"labels":["keller-potter.net","edwards.com","robinson.biz","smith.com","francis-ellis.com","turner.biz","martin.net","roy.net","atkinson.org","hale.com","mcclure.com","sutton.com","frank-mahoney.biz","soto.biz","jones-bradley.com","gar","wilson.org","garcia.biz","guerrero.com","lee.com"],"marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692","#B6E880","#FF97FF","#FECB52","#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692","#B6E880","#FF97FF","#FECB52"]},"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":[38,11,62,30,16,60,70,22,21,17,70,32,16,2,28,19,16,6,39,39],"type":"treemap"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern ...

# %%
data_martin = data[data['domain_name']=='martin.net']
questions = data.iloc[0, :]
print("Martin.net Respondents:", data_martin.shape[0])
# Out:
# Martin.net Respondents: 70

# %%
data_mcclure = data[data['domain_name']=='mcclure.com']
questions = data.iloc[0, :]
print("Mcclure.com Respondents:", data_mcclure.shape[0])
# Out:
# Mcclure.com Respondents: 70

# %%
data_soto = data[data['domain_name']=='soto.biz']
questions = data.iloc[0, :]
print("Soto.biz Respondents:", data_soto.shape[0])
# Out:
# Soto.biz Respondents: 2

# %%
#Count all domain name appearance 

data['domain_name'].value_counts()
# Out:
# martin.net           70
# mcclure.com          70
# robinson.biz         62
# turner.biz           60
# lee.com              39
# guerrero.com         39
# keller-potter.net    38
# sutton.com           32
# smith.com            30
# jones-bradley.com    28
# roy.net              22
# atkinson.org         21
# gar                  19
# hale.com             17
# francis-ellis.com    16
# frank-mahoney.biz    16
# wilson.org           16
# edwards.com          11
# garcia.biz            6
# soto.biz              2
# Name: domain_name, dtype: int64

# %% [markdown]
# # Displaying Distribution Percentage for each company.

# %%
#List of the companies involved
company_names=['lee.com','francis-ellis.com','hale.com','mcclure.com','robinson.biz','roy.net','sutton.com',
               'martin.net','atkinson.org','turner.biz','keller-potter.net','gar','guerrero.com','jones-bradley.com',
               'soto.biz','edwards.com','frank-mahoney.biz','smith.com','wilson.org','garcia.biz'] 

company = data[data['domain_name'].isin(company_names)]
company = company["domain_name"].value_counts(normalize=True, ascending=True) 

#Count the number of companies and express it as a fraction
company = company.mul(100) #multiply the values by 100 (i.e. percentage)
company = company.rename("percentage (%)").reset_index()
company = company.rename(columns={"index":"company"})
company = company.round(decimals=1) 


company["color"] = "gold" # color the others gold
company.loc[company["company"] == "martin.net", ["color"]] = "green" 

fig = px.bar(company, y="company", x="percentage (%)", text='percentage (%)', 
             title="Ranking of companies based on number of occurences in percentage (%)", orientation="h")
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside', marker_color=company.color) 
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', plot_bgcolor = "white")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="87d542ce-ace2-4253-b458-2933a397ac76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87d542ce-ace2-4253-b458-2933a397ac76")) {                    Plotly.newPlot(                        "87d542ce-ace2-4253-b458-2933a397ac76",                        [{"alignmentgroup":"True","hovertemplate":"percentage (%)=%{text}<br>company=%{y}<extra></extra>","legendgroup":"","marker":{"color":["gold","gold","gold","gold","gold","gold","gold","gold","gold","gold","gold","gold","gold","gold","gold","gold","gold","gold","green","gold"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[0.3,1.0,1.8,2.6,2.6,2.6,2.8,3.1,3.4,3.6,4.6,4.9,5.2,6.2,6.4,6.4,9.8,10.1,11.4,11.4],"textposition":"outside","x":[0.3,1.0,1.8,2.6,2.6,2.6,2.8,3.1,3.4,3.6,4.6,4.9,5.2,6.2,6.4,6.4,9.8,10.1,11.4,11.4],"xaxis":"x","y":["soto.biz","garcia.biz","edwards.com","francis-ellis.com","frank-mahoney.biz","wilson.org","hale.com","gar","atkinson.org","roy.net","jones-bradley.com","smith.com","sutton.com","keller-potter.net","lee.com","guerrero.com","turner.biz","robinson.biz","martin.net","mcclure.com"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[ ...

# %% [markdown]
# **Alternative:**

# %%
fig =  px.pie(data, names = "domain_name", hole = 0.4, template = "gridon")
fig.show ()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="19bbf150-4e44-4f7b-aa7d-2c2f399b1636" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19bbf150-4e44-4f7b-aa7d-2c2f399b1636")) {                    Plotly.newPlot(                        "19bbf150-4e44-4f7b-aa7d-2c2f399b1636",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"domain_name=%{label}<extra></extra>","labels":["lee.com","francis-ellis.com","hale.com","mcclure.com","robinson.biz","roy.net","sutton.com","martin.net","mcclure.com","atkinson.org","turner.biz","keller-potter.net","martin.net","gar","lee.com","guerrero.com","mcclure.com","martin.net","hale.com","robinson.biz","sutton.com","guerrero.com","roy.net","turner.biz","mcclure.com","turner.biz","mcclure.com","lee.com","turner.biz","martin.net","roy.net","jones-bradley.com","soto.biz","edwards.com","hale.com","hale.com","frank-mahoney.biz","lee.com","mcclure.com","mcclure.com","jones-bradley.com","mcclure.com","turner.biz","smith.com","turner.biz","smith.com","keller-potter.net","mcclure.com","mcclure.com","keller-potter.net","lee.com","francis-ellis.com","roy.net","mcclure.com","roy.net","robinson.biz","robinson.biz","turner.biz","martin.net","mcclure.com","keller-potter.net","robinson.biz","mcclure.com","turner.biz","wilson.org","hale.com","robinson.biz","garcia.biz","edwards.com","turner.biz","guerrero.com","roy.net","turner.biz","mcclure.com","frank-mahoney.biz","robinson.biz","sutton.com","roy.net","mcclure.com","robinson.biz","mcclure.com","martin.net","keller-potter.net","mcclure.com","wilson.org","smith.com","gar","sutton.com","lee.com","smith.com","martin.net","robinson.biz","sutton.com","turner.biz","frank-mahoney.biz","wilson.org","sutton.com","mcclure.com","martin.net","turner.biz","smith.com","lee.com","atkinson.org","mcclure.com","guerrero.com","martin.net","atkinson.org","lee.com","edwards.com","robinson.biz","francis-ellis.com","martin.net","edwards.com","turner.biz","keller-potter.net","mcclure.com","guerrero.com","turner.biz","gar","robinson.biz","atkinson.org","robinson.biz","martin.net","sutton.com","turner.biz","roy.net","garcia.biz","martin.net","mcclure.com","robinson.biz","keller-potter.net","mcclure.com","turner.biz","mcclure.com","lee.com","mcclure.com","gar","martin.net","jones-bradley.com","keller-potter.net","sutton.com","keller-potter.net","turner.biz","sutton.com","turner.biz","turner.biz","atkinson.org","guerrero.com","guerrero.com","guerrero.com","martin.net","jones-bradley.com","wilson.org","robinson.biz","keller-potter.net","martin.net","martin.net","jones-bradley.com","hale.com","mcclure.com","turner.biz","turner.biz","gar","martin.net","robinson.biz","lee.com","jones-bradley.com","guerrero.com","robinson.biz","mcclure.com","keller-potter.net","francis-ellis.com","lee.com","turner.biz","turner.biz","martin.net","roy.net","hale.com","martin.net","keller-potter.net","lee.com","turner.biz","turner.biz","sutton.com","frank-mahoney.biz","hale.com","mcclure.com","lee.com","turner.biz","atkinson.org","guerrero.com","guerrero.com","mcclure.com","mcclure.com","martin.net","martin.net","hale.com","martin.net","robinson.biz","jones-bradley.com","keller-potter.net","atkinson.org","robinson.biz","mcclure.com","guerrero.com","robinson.biz","smith.com","mcclure.com","atkinson.org","mcclure.com","edwards.com","jones-bradley.com","mcclure.com","mcclure.com","mcclure.com","mcclure.com","wilson.org","martin.net","gar","keller-potter.net","roy.net","smith.com","sutton.com","atkinson.org","sutton.com","frank-mahoney.biz","mcclure.com","gar","guerrero.com","keller-potter.net","lee.com","keller-potter.net","sutton.com","robinson.biz","wilson.org","atkinson.org","guerrero.com","atkinson.org","lee.com","robinson.biz","tur ...

# %% [markdown]
# #Showing highest amount spent on each of the subcription plan categories:

# %%
fig = px.histogram(data, x = "price",  facet_row = "plan",  template = 'plotly_dark')
fig.show ()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b9248e65-ef0f-4906-8258-1c7efe41955c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9248e65-ef0f-4906-8258-1c7efe41955c")) {                    Plotly.newPlot(                        "b9248e65-ef0f-4906-8258-1c7efe41955c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"plan=Professional<br>price=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[5400,6300,6600,5700,2100,4500,5700,6600,2100,5100,5400,3600,5700,3600,3600,6600,6600,3600,3600,1500,2100,6600,4200,3600,3600,3600,3600,1500,3600,4500,3600,3600,4500,3600,5400,3600,6300,5700,3600,5100,5700,2100,4200,4500,2100,5700,3600,2100,2100,5700,5700,1500,6600,5100,4500,5400,3600,1500,6600,4500,5400,5100,2100,3600,6600,5100,4500,5700,6600,5700,3600,4500,3600,5400,3600,6600,5700,2100,5700,5100,2100,5700,3900,4500,3600,5100,3600,5100,5400,5700,6600,3600,6300,4500,4500,2100,3600,2100,3600,6300,5400,5100,5400,1500,3600,4500,4200,4500,5700,6600,5100,3900,1500,3600,4200,1500,3600,5100,4500,3600,2100,6600,1500,1500,3600,4500,5700,5100,2100,2100,5400,5400,3600,6300,2100,5400,6300,2100,1500,2400,4500,3600,5400,5700,4500,5400,2100,6600,6300,3600,3900,3900,6300,4500,4500,4500,2100,3900,3600,6600,3600,6600,5400,3600,1500,3600,5100,3600,1500,1500,4500,5700,6600,4500,5100,4500,5100,3600,6300,3600,4200,5400,5700,5400,3600,3600,4500,2700,1500,2100,5700,5400,4500,4500,4500,1500,2100],"xaxis":"x3","yaxis":"y3","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"plan=Enterprise<br>price=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[4200,4200,8520,5160,5160,5160,9000,11400,9000,4200,5160,9000,6120,9480,2760,5160,5160,4200,4200,9480,9000,4200,11400,9000,4200,4200,5160,11400,8520,5640,8520,5160,4200,4200,5160,9000,5160,4200,6600,4200,11400,4200,9000,5160,4200,5160,11400,11400,8520,9000,9000,9000,2760,6120,9000,9480,5160,7560,4200,9000,4200,5160,7560,11400,5160,6600,9000,4200,6120,5160,8520,9000,4200,9000,8520,4200,6120,8040,9000,5160,5160,8520,5160,5160,5160,5160,11400,4200,8520,6600,7560,4200,8520,6600,5160,5160,4200,8040,4200,2760,5160,5640,5160,4200,5160,5160,4200,4200,5160,7560,5640,4200,7560,11400,4200,5160,8520,4200,5160,4200,4200,5640,5160,4200,6600,5160,9000,4680,5160,6600,2760,11400,6120,9000,5640,9000,4200,7560,6120,5160,5160,4200,9000,4200,9000,4200,5160,8520,2760,7560,5160,8520,5160,4200,4200,4200,8040,5160,4200,4200,5160,11400,9000,5160,4200,7560,7560,11400,4680,2760,8520,2760,4200,9000,5160,11400,4200,2760,5160,4200,2760,4200,5160,5160,5640,9000,6600,5160,11400,2760,4200,4200,9000,11400,4200,7560,9000,8040,11400,4200,9000,5160,11400,6120,2760,5640,5160,5160,4200,4200,4200,9000,5640,7560,5160,4200,2760,9000,5160,9000,6600,4200,8040,4200,5160,4200,5160,5160,6120,5160,11400,4200,2760],"xaxis":"x2","yaxis":"y2","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"plan=Engage<br>price=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[1800,1800,1560,2280,1920,2400,1560,1560,2400,1560,1560,1920,1560,1560,480,1440,2400,1560,1800,1560,480,600,960,840,1800,1560,600,1800,480,2280,960,1920,1800,1920,1920,2400,1800,1560,1920,1560,840,1560,2400,1920,480,1560,1800,1560,480,960,600,480,600,480,1440,1800,480,2280,840,840,600,600,840,1920,1560,2280,960,2400,1920,1800,1800,1560,840,960,840,600,600,600,2400,480,1560,2400,1800,1560,1800,2400,1800,1800,1920,480,480,1920, ...

# %%
#Let's see a plot of most subscribed plan by customers

fig =  px.pie(data, names = "plan", hole = 0.4, title = 'Most Subscribed Plan by Customers', template = "gridon")
fig.show ()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="05c04fe1-6a23-4ea4-b2ab-cc7526528102" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05c04fe1-6a23-4ea4-b2ab-cc7526528102")) {                    Plotly.newPlot(                        "05c04fe1-6a23-4ea4-b2ab-cc7526528102",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"plan=%{label}<extra></extra>","labels":["Professional","Professional","Professional","Enterprise","Enterprise","Engage","Engage","Professional","Engage","Enterprise","Professional","Enterprise","Professional","Enterprise","Enterprise","Enterprise","Engage","Professional","Professional","Engage","Enterprise","Enterprise","Engage","Professional","Engage","Professional","Engage","Professional","Professional","Professional","Engage","Enterprise","Professional","Professional","Professional","Professional","Professional","Enterprise","Enterprise","Engage","Enterprise","Engage","Professional","Engage","Enterprise","Enterprise","Enterprise","Engage","Engage","Engage","Enterprise","Engage","Engage","Engage","Engage","Enterprise","Enterprise","Enterprise","Professional","Engage","Engage","Engage","Enterprise","Professional","Engage","Professional","Enterprise","Professional","Professional","Professional","Engage","Engage","Professional","Engage","Professional","Engage","Enterprise","Engage","Enterprise","Enterprise","Enterprise","Professional","Engage","Engage","Engage","Engage","Enterprise","Professional","Engage","Engage","Professional","Engage","Enterprise","Professional","Professional","Engage","Engage","Engage","Professional","Professional","Engage","Professional","Enterprise","Engage","Engage","Enterprise","Enterprise","Enterprise","Professional","Enterprise","Professional","Professional","Professional","Enterprise","Enterprise","Engage","Enterprise","Professional","Enterprise","Enterprise","Enterprise","Enterprise","Professional","Enterprise","Professional","Engage","Professional","Professional","Enterprise","Engage","Engage","Enterprise","Professional","Engage","Engage","Engage","Enterprise","Professional","Enterprise","Enterprise","Enterprise","Engage","Professional","Enterprise","Professional","Professional","Enterprise","Enterprise","Enterprise","Enterprise","Professional","Enterprise","Engage","Engage","Engage","Professional","Professional","Enterprise","Professional","Enterprise","Enterprise","Professional","Enterprise","Professional","Enterprise","Professional","Enterprise","Enterprise","Engage","Enterprise","Engage","Engage","Enterprise","Professional","Enterprise","Professional","Engage","Professional","Professional","Engage","Professional","Professional","Professional","Enterprise","Professional","Professional","Engage","Enterprise","Professional","Enterprise","Engage","Engage","Enterprise","Enterprise","Professional","Professional","Professional","Professional","Engage","Enterprise","Enterprise","Enterprise","Engage","Enterprise","Engage","Enterprise","Engage","Enterprise","Enterprise","Enterprise","Professional","Enterprise","Engage","Enterprise","Enterprise","Engage","Engage","Professional","Enterprise","Enterprise","Engage","Engage","Engage","Enterprise","Engage","Professional","Engage","Enterprise","Engage","Enterprise","Enterprise","Enterprise","Enterprise","Enterprise","Engage","Enterprise","Engage","Enterprise","Professional","Engage","Enterprise","Engage","Enterprise","Professional","Enterprise","Engage","Enterprise","Engage","Engage","Engage","Professional","Enterprise","Professional","Professional","Enterprise","Engage","Enterprise","Enterprise","Engage","Enterprise","Engage","Engage","Enterprise","Engage","Enterprise","Professional","Enterprise","Engage","Enterprise","Professional","Enterprise","Engage"," ...

# %% [markdown]
# **Observation: 37.9% of the customers chose Enterprise plan, 32.1% chose Professional plan while 30% chose Engage plan.**

# %% [markdown]
# #Checking the newest and oldest recorded subcription dates.

# %%
data["date_subscription"] = pd.to_datetime(data["date_subscription"])
dates = []
for i in data["date_subscription"]:
    i = i.date()
    dates.append(i)  
#Dates of the newest and oldest recorded customer
print("The newest customer's subscription date in the records:",max(dates))
print("The oldest customer's subscription date in the records:",min(dates))
# Out:
# The newest customer's subscription date in the records: 2021-06-04
# The oldest customer's subscription date in the records: 2020-02-12

# %% [markdown]
# #Checking the newest and oldest recorded sign-up dates

# %%
data["date_signup"] = pd.to_datetime(data["date_signup"])
dates = []
for i in data["date_signup"]:
    i = i.date()
    dates.append(i)  
#Dates of the newest and oldest recorded customer
print("The newest customer's sign-up date in the records:",max(dates))
print("The oldest customer's sign-up date in the records:",min(dates))
# Out:
# The newest customer's sign-up date in the records: 2021-04-08
# The oldest customer's sign-up date in the records: 2020-01-25

# %% [markdown]
# **DERIVING TOTAL NUMBER OF DAYS THAT EACH CUSTOMER COMPANY WAS FULLY ENGAGED WITH SLIDO IN TERMS OF SUBSCRIPTION**

# %%
from datetime import datetime

to_day = datetime.today().strftime('%Y-%m-%d')
today = pd.to_datetime(to_day)

data['date_subscription'] = pd.to_datetime(data.date_subscription)
data['Day_engaged'] = (today - data['date_subscription']).dt.days

# %% [markdown]
# **DERIVING LIFESPAN OF EACH CUSTOMER COMPANY WITH SLIDO (in days)**

# %%
data['date_signup'] = pd.to_datetime(data.date_signup)
data['Customer_lifespan'] = (today - data['date_signup']).dt.days

# %%
data.head()
# Out:
#          domain_name  users          plan  price  event_id  \
# 0            lee.com     16  Professional   5400         7
# 1  francis-ellis.com     19  Professional   6300         8
# 2           hale.com     20  Professional   6600        16
# 3        mcclure.com      5    Enterprise   4200        17
# 4       robinson.biz      5    Enterprise   4200        27
#
#    joined_participants  active_participants  avg_join  avg_active date_signup  \
# 0                  143                   88       143          88  2020-02-12
# 1                   80                   68        80          68  2020-11-09
# 2                   93                   51        93          51  2020-06-08
# 3                  136                  128       136         128  2020-05-04
# 4                  161                   93       161          93  2020-01-25
#
#   date_subscription        date  Day_engaged  Customer_lifespan
# 0        2020-02-12  2020-12-29          777                777
# 1        2020-11-16  2021-02-05          499                506
# 2        2020-07-18  2021-01-23          620                660
# 3        2020-05-21  2021-01-09          678                695
# 4        2020-02-26  2020-10-27          763                795

# %% [markdown]
# #Deriving total number of years spent so far by each customer company with the Slido

# %%
#ADDING A COLUMN "year_spent" IN THE DATAFRAME
data['year_spent'] = (pd.Timestamp('now').year) - (pd.to_datetime(data['date_signup']).dt.year)

#CHECKING NUMBER OF UNIQUE CATEGORIES PRESENT IN THE "year_spent"
print("Unique categories present in the year_spent:",data['year_spent'].value_counts())
print("\n")


#VISUALIZING THE "year_spent"
data['year_spent'].value_counts().plot(kind='bar',color = 'turquoise',edgecolor = "black",linewidth = 3)
plt.title("Frequency Of Each Category in the year_spent Variable \n",fontsize=24)
plt.figure(figsize=(8,8))
# Out:
# Unique categories present in the year_spent: 2    575
# 1     39
# Name: year_spent, dtype: int64

# %% [markdown]
# #OBSERVATIONS:-
#
# - **57.00% are 2 years old customers.**
# - **43.00% are 1 year old customers.**

# %% [markdown]
# #How subcription plan impacts or affects the price?

# %%
sns.set_theme(style="white")
plt.figure(figsize=(8,8))
plt.title("How subcription plan impacts or affects the price?",fontsize=24)
ax = sns.barplot(x="plan", y="price", data=data,palette="rainbow")

# %% [markdown]
# **Observation: Most money was spent on enterprise plan by our customers**

# %% [markdown]
# **Account users and subcription plan?**

# %%
sns.set_theme(style="white")
plt.figure(figsize=(8,8))
plt.title("Account Users and The Subscription Plan",fontsize=24)
ax = sns.barplot(x="plan", y="users", data=data,palette="rainbow")

# %% [markdown]
# **Observation: Professional plan had more users followed by Engage then Enterprise**

# %% [markdown]
# #Total cost spent by each company on subcription

# %%
sns.set_theme(style="white")
plt.figure(figsize=(16,16))
plt.title("Total Monetary Value spent by each company on subcription",fontsize=24)
ax = sns.barplot(x="price", y="domain_name", data=data,palette="rainbow")

# %% [markdown]
# #It is important we know the customers that subscribed most to each plan

# %%
#Professional Plan

prof_plan = data[data['plan'] == 'Professional']


sns.set_theme(style="white")
plt.figure(figsize=(16,16))
plt.title("Company That Spent Most On Professional subcription",fontsize=24)
ax = sns.barplot(x='price', y="domain_name", data=prof_plan,palette="rainbow")

# %%
#Enterprise Plan

enter_plan = data[data['plan'] == 'Enterprise']

sns.set_theme(style="white")
plt.figure(figsize=(16,16))
plt.title("Company That Spent Most On Enterprise subcription",fontsize=24)
ax = sns.barplot(x='price', y="domain_name", data=enter_plan.sort_values(by='price', ascending=False),palette="rainbow")

# %%
#Engage Plan

eng_plan = data[data['plan'] == 'Engage']

sns.set_theme(style="white")
plt.figure(figsize=(16,16))
plt.title("Company That Spent Most On Engage Plan",fontsize=24)
ax = sns.barplot(x='price', y="domain_name", data=eng_plan,palette="rainbow")

# %% [markdown]
# **Observation:**
#  - **Hale.com, Lee.com and Francis-ellis.com** as spent the most money on professional plan
#  - **Sutton.net and Guerrero.com** spent the most money on enterprise pla
#  - **Roy.net, Smith.com, Lee.com and Sutton.net** spent the most money on engage plan

# %%
#Let's take a look at the different plans by each customer company

data.groupby(['domain_name', 'plan'])['plan'].count()
# Out:
# domain_name        plan
# atkinson.org       Enterprise      21
# edwards.com        Professional    11
# francis-ellis.com  Engage           7
#                    Professional     9
# frank-mahoney.biz  Professional    16
# gar                Enterprise      19
# garcia.biz         Professional     6
# guerrero.com       Engage          21
#                    Enterprise      18
# hale.com           Professional    17
# jones-bradley.com  Enterprise      28
# keller-potter.net  Engage          17
#                    Enterprise      21
# lee.com            Engage           5
#                    Enterprise      16
#                    Professional    18
# martin.net         Enterprise       8
#                    Professional    62
# mcclure.com        Engage          34
#                    Enterprise      36
# robinson.biz       Engage          31
#                    Enterprise      30
#                    Professional     1
# roy.net            Engage          22
# smith.com          Engage          19
#                    Enterprise       6
#                    Professional     5
# soto.biz           Professional     2
# sutton.com         Engage          12
#                    Enterprise      18
#                    Professional     2
# turner.biz         Enterprise      12
#                    Professional    48
# wilson.org         Engage          16
# Name: plan, dtype: int64

# %% [markdown]
# #Number of active participants from each company respectively.

# %%
sns.set_theme(style="white")
plt.figure(figsize=(16,16))
plt.title("Active participants from each company",fontsize=24)
ax = sns.barplot(x="active_participants", y="domain_name", data=data,palette="rainbow")

# %% [markdown]
# **Deriving percentage of active participants out of total number of participants from each company.**

# %%
#Percentage of active participants per company

data['active_participants_percentage'] = (data['active_participants']/data['joined_participants'])*100 
data['active_participants_percentage'] = data['active_participants_percentage'].round(2)   #Round to 2 decimal places

# %%
sns.set_theme(style="white")
plt.figure(figsize=(16,16)) 
plt.title("Active participants Percentage from each company",fontsize=24)
ax = sns.barplot(x="active_participants_percentage", y="domain_name", data=data, palette="rainbow")

# %%
data.head(2)
# Out:
#          domain_name  users          plan  price  event_id  \
# 0            lee.com     16  Professional   5400         7
# 1  francis-ellis.com     19  Professional   6300         8
#
#    joined_participants  active_participants  avg_join  avg_active date_signup  \
# 0                  143                   88       143          88  2020-02-12
# 1                   80                   68        80          68  2020-11-09
#
#   date_subscription        date  Day_engaged  Customer_lifespan  year_spent  \
# 0        2020-02-12  2020-12-29          777                777           2
# 1        2020-11-16  2021-02-05          499                506           2
#
#    active_participants_percentage
# 0                           61.54
# 1                           85.00

# %% [markdown]
# **Number of users under each account**

# %%
sns.set_theme(style="white")
plt.figure(figsize=(16,16))
plt.title("Number of Users For Each Company Account",fontsize=24)
ax = sns.barplot(x="users", y="domain_name", data=data,palette="rainbow")

# %% [markdown]
# **How total number of Day_engaged impacts on each customer company?**

# %%
sns.set_theme(style="white")
plt.figure(figsize=(16,16))
plt.title("How total number of Day_engaged impacts on each customer company?",fontsize=24)
ax = sns.barplot(x="Day_engaged", y="domain_name", data=data,palette="rainbow")

# %% [markdown]
# **How total number of Day_engaged impacts on each subcription plan category?**

# %%
sns.set_theme(style="white")
plt.figure(figsize=(16,16))
plt.title("How total number of Day_engaged impacts on each subcription plan category?",fontsize=24)
ax = sns.barplot(x="Day_engaged", y="plan", data=data,palette="rainbow")

# %% [markdown]
# #Analysis On price Variable

# %%
#Let's see a plot of price distribution

plt.figure(figsize=(8,8))
sns.distplot(data["price"],color = 'turquoise')
plt.show()
data["price"].plot.box(figsize=(8,8),color = 'turquoise')
plt.show()

# %% [markdown]
# Displaying relationship among all given variables using "**Correlation Matrix**" below:

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(), annot=True,cmap = 'Greys',linewidths=1)

# %% [markdown]
# **Slido aims to maximize profit, it will be very much necessary to test how "price" affects other numerical variables.**

# %%
num_cols = data.select_dtypes(include = 'number').columns.to_list() # numerical features
num_cols
# Out:
# ['users',
#  'price',
#  'event_id',
#  'joined_participants',
#  'active_participants',
#  'avg_join',
#  'avg_active',
#  'Day_engaged',
#  'Customer_lifespan',
#  'year_spent',
#  'active_participants_percentage']

# %%
cont_features = data[num_cols]
print(type(cont_features))
print('\n')
print(cont_features.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
#
#    users  price  event_id  joined_participants  active_participants  avg_join  \
# 0     16   5400         7                  143                   88       143
# 1     19   6300         8                   80                   68        80
# 2     20   6600        16                   93                   51        93
# 3      5   4200        17                  136                  128       136
# 4      5   4200        27                  161                   93       161
#
#    avg_active  Day_engaged  Customer_lifespan  year_spent  \
# 0          88          777                777           2
# 1          68          499                506           2
# 2          51          620                660           2
# 3         128          678                695           2
# 4          93          763                795           2
#
#    active_participants_percentage
# 0                           61.54
# 1                           85.00
# 2                           54.84
# 3                           94.12
# 4                           57.76

# %%
import matplotlib
background_color = "#f6f5f5"

fig = plt.figure(figsize=(16, 8), facecolor=background_color)
gs = fig.add_gridspec(1, 1)
ax0 = fig.add_subplot(gs[0, 0])
colors = ["#2f5586", "#f6f5f5","#2f5586"]
colormap = matplotlib.colors.LinearSegmentedColormap.from_list("", colors)

ax0.set_facecolor(background_color)
ax0.text(-1.1, 1.25, 'Correlation of Continuous Features with price', fontsize=20, fontweight='bold')

chart_df = pd.DataFrame(cont_features.corrwith(data['price']))
chart_df.columns = ['corr']
sns.barplot(x=chart_df.index, y=chart_df['corr'], ax=ax0, color='turquoise', zorder=3, edgecolor='black', linewidth=3)
ax0.grid(which='major', axis='x', zorder=0, color='#EEEEEE', linewidth=0.4)
ax0.grid(which='major', axis='y', zorder=0, color='#EEEEEE', linewidth=0.4)
ax0.set_ylabel('')

for s in ["top","right", 'left']:
    ax0.spines[s].set_visible(False)

plt.show()

# %% [markdown]
# **Observation:** From the figure above, the variable "users" has the highest positive correlation value of approximately 0.47 (which can be confirmed in correlation matrix drawn above) while others have relatively negligible values (i.e very low or negative correlation values) when compared to users correlation value. Henceforth, it can be deduced that the higher the number of users, the higher the sales/price and the higher the profit generated by Slido.

# %% [markdown]
# **Now, let's display the number of active users under the subscription software accounts from each customer company to make our final conclusion.**

# %%
sns.set_theme(style="white")
plt.figure(figsize=(16,16))
plt.title("Number of active users under the subscription software accounts from each customer company",fontsize=24)
ax = sns.barplot(x="users", y="domain_name", data=data,palette="rainbow")

# %% [markdown]
# #CONCLUSION:
# In reference to my findings, aim and objectives of this analysis, it can be concluded from the diagram above that out of twenty(20) companies(customers) that patronize us, only **"keller.potter.net", "jones.bradley.com" & "gar"** happened to have lowest number of active software users especially if we choose 7 to be threshold (i.e our minimum number of users to be considered). Henceforth, based on their activity, all other companies worth going after for deals except the three aforementioned companies above that fall below our threshold value (7).
# >Some our top customers include: **hale.com, roy.net, sutton.net, lee.com, francis-ellis.com, guerrero.com, smith.com**. They spent the most money on different annual plans and also from the graph above have most users which affect the price and sales directly.
